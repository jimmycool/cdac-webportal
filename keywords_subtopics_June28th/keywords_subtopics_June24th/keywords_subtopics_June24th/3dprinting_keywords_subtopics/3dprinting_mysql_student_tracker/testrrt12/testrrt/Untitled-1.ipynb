# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
# ...

# %%
print("hello")
# Out:
# hello

# %%
def small_pal(i):
    flag=True
    num=None
    while(flag):
        num=str(i+1)
        pal=""
        for g in num:
            pal=g+pal
        if(pal==num):
            flag=False
    return num 
test=int(input())
for i in test:
  b=int(input())
  print(small_pal(b))

# %%
# !pip install python-jose
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------- ----------------------------- 1/4 [ecdsa]
#    ------------------------------ --------- 3/4 [python-jose]
#    ---------------------------------------- 4/4 [python-jose]
#
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\CCT-ITM 05\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
# ...

# %%
import pandas as pd
rootDir="C:/Users/CCT-ITM 05/Downloads/playground-series-s6e5/"
train_file=rootDir+"train.csv"
test_file=rootDir+"test.csv"
pd1=pd.read_csv(train_file)
pd2=pd.read_csv(test_file)

# %%
X=pd1[pd1.columns[1:-1]]
y=pd1[pd1.columns[len(pd1.columns)-1]]
Xtest=pd2[pd2.columns[1:]]
print(len(Xtest.columns),len(X.columns))
# Out:
# 14 14

# %%
print(Xtest.columns,len(Xtest.columns))
print(X.columns,len(X.columns))
# Out:
# Index(['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint',
#        'TyreLife', 'Position', 'LapTime (s)', 'LapTime_Delta',
#        'Cumulative_Degradation', 'RaceProgress', 'Position_Change'],
#       dtype='str') 14
# Index(['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint',
#        'TyreLife', 'Position', 'LapTime (s)', 'LapTime_Delta',
#        'Cumulative_Degradation', 'RaceProgress', 'Position_Change'],
#       dtype='str') 14

# %%
X['Position_Change'].unique()
# Out:
# array([  5.,  -3.,   3.,   0.,  -9.,   4.,   6.,  -1.,  -2.,   2.,   7.,
#         -4.,   1.,  -8.,   8.,  -5.,   9.,  11.,  14.,  -6., -10., -11.,
#         -7.,  10.,  13., -16., -12., -14., -13., -15.,  15.,  12.,  17.,
#        -18.,  16., -17.,  18.])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['Compound']=le.fit_transform(X['Compound'])
X['Race']=le.fit_transform(X['Race'])
Xtest['Compound']=le.fit_transform(Xtest['Compound'])
Xtest['Race']=le.fit_transform(Xtest['Race'])

# %%
X=X[X.columns[1:]]
X.head(5)
# Out:
#    Race  Year  PitStop  LapNumber  Stint  TyreLife  Position  LapTime (s)  \
# 0     7  2022        0         50      2      39.0         8       78.491
# 1     9  2025        1         27      2       7.0         4       75.095
# 2     2  2022        0         59      3      22.0        13       70.945
# 3    19  2023        0          2      1       2.0         7       94.361
# 4     3  2022        1         26      3       6.0         2      107.878
#
#    LapTime_Delta  Cumulative_Degradation  RaceProgress  Position_Change
# 0         -7.564                  21.019      0.714286              5.0
# 1        -32.617                -223.207      0.346154             -3.0
# 2         -7.540                -100.529      0.819444              3.0
# 3         -7.324                  -7.324      0.076923              0.0
# 4          8.965                 -14.139      0.361111              3.0

# %%
Xtest.columns
# Out:
# Index(['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint',
#        'TyreLife', 'Position', 'LapTime (s)', 'LapTime_Delta',
#        'Cumulative_Degradation', 'RaceProgress', 'Position_Change'],
#       dtype='str')

# %%
X.columns
# Out:
# Index(['Driver', 'Compound', 'Race', 'Year', 'PitStop', 'LapNumber', 'Stint',
#        'TyreLife', 'Position', 'LapTime (s)', 'LapTime_Delta',
#        'Cumulative_Degradation', 'RaceProgress', 'Position_Change'],
#       dtype='str')

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.20)

# %%
# Out:
# 314422    0.0
# 93554     0.0
# 328610    0.0
# 154352    0.0
# 291282    1.0
# Name: PitNextLap, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X[X.columns[1:]],y)
# Out:
# C:\Users\CCT-ITM 05\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=lr.predict(Xtest[Xtest.columns[1:]])
dict1={'id':[],'PitNextLap':[]}

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_pred,ytest))
# Out:
# [[68674 15218]
#  [ 1553  2383]]

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File e:\python\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File e:\python\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *
#
# ImportError: DLL load failed while importing _multiarray_umath: A dynamic link library (DLL) initialization routine failed.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File e:\python\Lib\site-packages\pandas\__init__.py:23
#      22 try:
# ---> 23     __import__(_dependency)
#      24 except ImportError as _e:  # pragma: no cover
#
# ...

# %%
import seaborn as sns
sns.heatmap(confusion_matrix(y_pred,ytest),annot=True,fmt="0.3f")
# Out:
# <Axes: >

# %%
import pandas as pd
pd1=pd.read_csv("user_pass.csv")
pd1.head(5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File e:\python\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File e:\python\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *
#
# ImportError: DLL load failed while importing _multiarray_umath: A dynamic link library (DLL) initialization routine failed.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File e:\python\Lib\site-packages\pandas\__init__.py:23
#      22 try:
# ---> 23     __import__(_dependency)
#      24 except ImportError as _e:  # pragma: no cover
#
# ...

# %%
import pandas as pd
pd1=pd.read_csv(r"C:\Users\AMITAVO\Downloads\archive (1)\cleaned_dataset\data\00001.csv")
pd1.head(5)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.14.6' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip freeze requirements.txt
# Out:
# anyio==4.14.1
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# arrow==1.4.0
# asgiref==3.11.1
# asttokens==3.0.1
# async-lru==2.3.0
# attrs==26.1.0
# babel==2.18.0
# beautifulsoup4==4.15.0
# bleach==6.4.0
# certifi==2026.6.17
# cffi==2.1.0
# charset-normalizer==3.4.9
# colorama==0.4.6
# comm==0.2.3
# debugpy==1.8.21
# decorator==5.3.1
# defusedxml==0.7.1
# Django==6.0.7
# django-taggit==6.1.0
# executing==2.2.1
# fastjsonschema==2.21.2
# fqdn==1.5.1
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.18
# ipykernel==7.3.0
# ipython==9.15.0
# ipython_pygments_lexers==1.1.1
# isoduration==20.11.0
# jedi==0.20.0
# Jinja2==3.1.6
# json5==0.15.0
# jsonpointer==3.1.1
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter-events==0.12.1
# jupyter-lsp==2.3.1
# jupyter_builder==1.0.2
# jupyter_client==8.9.1
# jupyter_core==5.9.1
# jupyter_server==2.20.0
# jupyter_server_terminals==0.5.4
# jupyterlab==4.6.1
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.28.0
# ...

# %%
# !pip install numpy --upgrade
